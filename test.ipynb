# %%
# !pip install pandas-market-calendars

# %%
from generate_periods import get_train_periods
from config import Config

# %%
config = Config()

# %%
config.experiment.test_period_months
# Out:
# 1

# %%
train_periods = get_train_periods('2018-01-01', '2018-12-31', config)
train_periods
# Out:
# [['2015-03-31',
#   '2017-11-30',
#   '2015-03-31',
#   '2017-10-30',
#   '2017-10-30',
#   '2017-11-30',
#   '2017-12-11',
#   '2018-01-11'],
#  ['2015-03-31',
#   '2017-12-31',
#   '2015-03-31',
#   '2017-11-30',
#   '2017-11-30',
#   '2017-12-31',
#   '2018-01-11',
#   '2018-02-11'],
#  ['2015-03-31',
#   '2018-01-31',
#   '2015-03-31',
#   '2017-12-31',
#   '2017-12-31',
#   '2018-01-31',
#   '2018-02-09',
#   '2018-03-09'],
#  ['2015-03-31',
#   '2018-02-28',
#   '2015-03-31',
#   '2018-01-28',
#   '2018-01-28',
#   '2018-02-28',
#   '2018-03-09',
#   '2018-04-09'],
#  ['2015-03-31',
#   '2018-03-31',
#   '2015-03-31',
#   '2018-02-28',
#   '2018-02-28',
#   '2018-03-31',
#   '2018-04-11',
#   '2018-05-11'],
#  ['2015-03-31',
#   '2018-04-30',
#   '2015-03-31',
#   '2018-03-30',
#   '2018-03-30',
#   '2018-04-30',
#   '2018-05-09',
#   '2018-06-09'],
#  ['2015-03-31',
#   '2018-05-31',
#   '2015-03-31',
#   '2018-04-30',
#   '2018-04-30',
#   '2018-05-31',
#   '2018-06-11',
# ...
